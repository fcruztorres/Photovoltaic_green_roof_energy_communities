# %%
#install python (and check the add to path option during installation), then install the ema_workbench python module.
#this can be done by executing the following command in the command prompt:
# pip install ema_workbench

#import necessary python libraries for the analysis
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

#import EMA workbench tools
from ema_workbench.em_framework import samplers, evaluators, util
from ema_workbench import (RealParameter, ScalarOutcome, Model, Constant)
from ema_workbench import (perform_experiments, ema_logging, save_results, 
                           load_results, SequentialEvaluator)
ema_logging.log_to_stderr(ema_logging.INFO)


#import PRIM algorithm
from ema_workbench.analysis import prim
# Out:
# C:\Users\Timme\Anaconda3\lib\importlib\_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# C:\Users\Timme\Anaconda3\lib\importlib\_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)

# %% [markdown]
# # 1. Load the data for the global and local analysis

# %%
raw_data = pd.read_csv("Data/Costs and benefits of photovoltaic-green roofs.csv")
raw_data
# Out:
#                   Technology Green roof type Plant species     Irrigation  \
# 0    Photovoltaic-green roof       Extensive           NaN  not mentioned
# 1    Photovoltaic-green roof       Extensive           NaN  not mentioned
# 2    Photovoltaic-green roof       Extensive           NaN  not mentioned
# 3    Photovoltaic-green roof       Extensive           NaN  not mentioned
# 4    Photovoltaic-green roof       Extensive           NaN  not mentioned
# ..                       ...             ...           ...            ...
# 855                      NaN             NaN           NaN            NaN
# 856                      NaN             NaN           NaN            NaN
# 857                      NaN             NaN           NaN            NaN
# 858                      NaN             NaN           NaN            NaN
# 859                      NaN             NaN           NaN            NaN
#
#     PV panel type PV panels and GR locations  Distance PV-green roof [cm]  \
# 0             NaN              Same location                          NaN
# 1             NaN              Same location                          NaN
# 2             NaN              Same location                          NaN
# 3             NaN              Same location                          NaN
# 4             NaN              Same location                          NaN
# ..            ...                        ...                          ...
# 855           NaN                        NaN                          NaN
# 856           NaN                        NaN                          NaN
# 857           NaN                        NaN                          NaN
# 858           NaN                        NaN                          NaN
# 859           NaN                        NaN                          NaN
#
#      Distance PV-basecase roof [cm]          Season Base case roof situation  \
# 0                               NaN  annual average        To be constructed
# 1                               NaN  annual average        To be constructed
# 2                               NaN  annual average        To be constructed
# 3                               NaN  annual average        To be constructed
# 4                               NaN  annual average        To be constructed
# ..                              ...             ...                      ...
# 855                             NaN             NaN                      NaN
# 856                             NaN             NaN                      NaN
# 857                             NaN             NaN                      NaN
# 858                             NaN             NaN                      NaN
# 859                             NaN             NaN                      NaN
#
#      ... Unnamed: 67 Unnamed: 68 Unnamed: 69 Unnamed: 70 Unnamed: 71  \
# 0    ...         NaN         NaN         NaN         NaN         NaN
# 1    ...         NaN         NaN         NaN         NaN         NaN
# 2    ...         NaN         NaN         NaN         NaN         NaN
# 3    ...         NaN         NaN         NaN         NaN         NaN
# 4    ...         NaN         NaN         NaN         NaN         NaN
# ..   ...         ...         ...         ...         ...         ...
# 855  ...         NaN         NaN         NaN         NaN         NaN
# 856  ...         NaN         NaN         NaN         NaN         NaN
# 857  ...         NaN         NaN         NaN         NaN         NaN
# 858  ...         NaN         NaN         NaN         NaN         NaN
# 859  ...         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 72 Unnamed: 73 Unnamed: 74  Unnamed: 75 Unnamed: 76
# 0           NaN         NaN         NaN          NaN         NaN
# 1           NaN         NaN         NaN          NaN         NaN
# 2           NaN         NaN         NaN          NaN         NaN
# 3           NaN         NaN         NaN          NaN         NaN
# 4           NaN         NaN         NaN          NaN         NaN
# ..          ...         ...         ...          ...         ...
# 855         NaN         NaN         NaN          NaN         NaN
# 856         NaN         NaN         NaN          NaN         NaN
# 857         NaN         NaN         NaN          NaN         NaN
# 858         NaN         NaN         NaN          NaN         NaN
# 859         NaN         NaN         NaN          NaN         NaN
#
# [860 rows x 77 columns]

# %%
raw_data.columns
# Out:
# Index(['Technology', 'Green roof type', 'Plant species', 'Irrigation',
#        'PV panel type', 'PV panels and GR locations',
#        'Distance PV-green roof [cm]', 'Distance PV-basecase roof [cm]',
#        'Season', 'Base case roof situation', 'Building type', 'Base case roof',
#        'Base case insulation', 'Roof slope', 'Item', 'Item type', 'Item scale',
#        'Item class', 'Original monetary value', 'u.m.',
#        'Original year(s) at which the item is accounted',
#        'Green roof lifetime [years]',
#        'Actual year(s) at which the item is accounted',
#        'Actual monetary value at the accounting year',
#        'Inflation adjustment ratio [GDP deflator 2020/GDP deflator year]',
#        'PPP Exchange rate [€ EU27-2020/ local currency-2020]',
#        'Adjusted Monetary value [EU27 2020 €/m2]', 'Method for monetary value',
#        'Quantiative absolute evaluation', 'u.m.3',
#        'Method for absolute evaluation', 'Quantiative absolute evaluation 2',
#        'u.m. 3', 'Method for absolute evaluation 2', 'Climate', 'Continent',
#        'Country', 'City', 'Authors', 'Year', 'Title', 'Study type',
#        'WTP Correction factor [GDPpc,EU27-year/GDPpc,country-year)',
#        'Unusable monetary value', 'Case-study ID', 'Old inflaction correction',
#        'Old PPP exchange', 'Old adjusted value', 'Unnamed: 48', 'Unnamed: 49',
#        'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53',
#        'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57',
#        'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61',
#        'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64', 'Unnamed: 65',
#        'Unnamed: 66', 'Unnamed: 67', 'Unnamed: 68', 'Unnamed: 69',
#        'Unnamed: 70', 'Unnamed: 71', 'Unnamed: 72', 'Unnamed: 73',
#        'Unnamed: 74', 'Unnamed: 75', 'Unnamed: 76'],
#       dtype='object')

# %%
raw_data.Item.unique()
# Out:
# array(['Urban heat island effect mitigation',
#        'Air quality enhancement and CO2 reduction',
#        'Flood risk reduction',
#        'Stormwater management (without flood risk reduction)',
#        'Water runoff quality increase', 'Urban noise reduction',
#        'Biodiversity enhancement',
#        'Energy consumption reduction (cooling)',
#        'Energy consumption reduction (heating)',
#        'Energy consumption reduction (heating and cooling)',
#        'Sound insulation', 'Aesthetics increase',
#        'Replacement of vegetation cover', 'Replacement of drainage layer',
#        'Replacement and disposal of green roof',
#        'Photovoltaic performance increase',
#        'Installation of green roof (net)',
#        'Maintenance of green roof (without drainage and vegetation layer replacements)',
#        'Longevity increase', 'Fire risk reduction',
#        'Maintenance of green roof (net)', 'Incentive',
#        'Air quality enhancement', 'CO2 emission reduction',
#        'Stormwater management', 'Regulatory water-related costs',
#        'Installation of green roof (gross)', 'Property value increase',
#        'Stormwater management (retention of stormwater)',
#        'Stormwater management (avoided stormwater in drainage system)',
#        'Maintenance of green roof (gross)',
#        'Air pollution from green roof production',
#        'CO2 emissions from green roof production',
#        'Disposal of green roof', 'CO2 uptake', 'Stormwater reuse',
#        'Energy consumption reduction',
#        'Removal and disposal of prior roof', 'Replacement of green roof',
#        'Electricity generation', 'Groundwater recharging',
#        'Energy consumption reduction (all appliances)',
#        "Local area's property value increase",
#        'Installation of green roof without feasibility inspection (gross)',
#        'Feasibility inspection', 'Installation of PV panels',
#        'Job creation', 'Installation of white roof',
#        'Maintenance of white roof', "Local area's aesthetics increase",
#        'Comfort increase', nan, "Sound insulation (user's comfort)",
#        'Sound insulation (property value)'], dtype=object)

# %%
# Selection of global analysis' data

# Only aggregated versions of benefits (e.g., energy consumption total, instead of energy consumption cooling only) are kept
# and differential values with respect of the construction of the alternative basecase roof (i.e., net values) are kept. 
# This choice is due to the fact that net values are more numerous than gross values.

global_items = raw_data[((raw_data["Technology"] == "Green roof") | 
                         (raw_data["Technology"] == "Photovoltaic-green roof") ) &
                        (raw_data["Unusable monetary value"] != "x") &
                        ((raw_data["Item"] == "Urban heat island effect mitigation") |
                        (raw_data["Item"] == "Water runoff quality increase") |
                        (raw_data["Item"] == "Urban noise reduction") |
                        (raw_data["Item"] == "Biodiversity enhancement") |
                        (raw_data["Item"] == "Energy consumption reduction (heating and cooling)") |
                        (raw_data["Item"] == "Sound insulation") |
                        (raw_data["Item"] == "Aesthetics increase") |
                        (raw_data["Item"] == "Replacement and disposal of green roof") |
                        (raw_data["Item"] == "Installation of green roof (net)") |
                        (raw_data["Item"] == "Longevity increase") |
                        (raw_data["Item"] == "Fire risk reduction") |
                        (raw_data["Item"] == "Maintenance of green roof (net)") |
                        (raw_data["Item"] == "Air quality enhancement") |
                        (raw_data["Item"] == "CO2 emission reduction") |
                        (raw_data["Item"] == "Stormwater management") |
                        (raw_data["Item"] == "Air pollution from green roof production") |
                        (raw_data["Item"] == "CO2 emissions from green roof production") |
                        (raw_data["Item"] == "CO2 uptake") |
                        (raw_data["Item"] == "Electricity generation") |
                        (raw_data["Item"] == "Water runoff quality increase") |
                        (raw_data["Item"] == "Local area's aesthetics increase") |
                        (raw_data["Item"] == "Installation of PV panels"))]

global_items = global_items[["Item","Item type", "Actual year(s) at which the item is accounted", "Adjusted Monetary value [EU27 2020 €/m2]"]]

global_costs = global_items[ (global_items["Item type"]=="cost") ]
global_benefits = global_items[ (global_items["Item type"]=="benefit") ]
display(global_costs)
display(global_benefits)
# Out:
#                                        Item Item type  \
# 77   Replacement and disposal of green roof      cost
# 82   Replacement and disposal of green roof      cost
# 87         Installation of green roof (net)      cost
# 89   Replacement and disposal of green roof      cost
# 92   Replacement and disposal of green roof      cost
# ..                                      ...       ...
# 775         Maintenance of green roof (net)      cost
# 776         Maintenance of green roof (net)      cost
# 777         Maintenance of green roof (net)      cost
# 778         Maintenance of green roof (net)      cost
# 779         Maintenance of green roof (net)      cost
#
#     Actual year(s) at which the item is accounted  \
# 77                                      last year
# 82                                      last year
# 87                                              0
# 89                                      last year
# 92                                      last year
# ..                                            ...
# 775                                    every year
# 776                                    every year
# 777                                    every year
# 778                                    every year
# 779                                    every year
#
#      Adjusted Monetary value [EU27 2020 €/m2]
# 77                                  19.779366
# 82                                  19.766926
# 87                                  51.612949
# 89                                  30.141763
# 92                                  19.941084
# ..                                        ...
# 775                                  3.184810
# 776                                  4.028232
# 777                                  3.184810
# 778                                  3.523174
# 779                                  3.184810
#
# [138 rows x 4 columns]
#                                     Item Item type  \
# 0    Urban heat island effect mitigation   benefit
# 1    Urban heat island effect mitigation   benefit
# 2    Urban heat island effect mitigation   benefit
# 3    Urban heat island effect mitigation   benefit
# 4    Urban heat island effect mitigation   benefit
# ..                                   ...       ...
# 809                Stormwater management   benefit
# 810                Stormwater management   benefit
# 814                Stormwater management   benefit
# 815                Stormwater management   benefit
# 816                Stormwater management   benefit
#
#     Actual year(s) at which the item is accounted  \
# 0                                      every year
# 1                                      every year
# 2                                      every year
# 3                                      every year
# 4                                      every year
# ..                                            ...
# 809                                    every year
# 810                                    every year
# 814                                    every year
# 815                                    every year
# 816                                    every year
#
#      Adjusted Monetary value [EU27 2020 €/m2]
# 0                                    0.124399
# 1                                    0.124399
# 2                                    0.124399
# 3                                    0.124399
# 4                                    0.124399
# ..                                        ...
# 809                                  0.049980
# 810                                  0.044064
# 814                                  0.026724
# 815                                  0.033762
# 816                                  0.024072
#
# [359 rows x 4 columns]

# %%
# Selection of local analysis' data

local_items = raw_data[((raw_data["Technology"] == "Green roof") | 
                         (raw_data["Technology"] == "Photovoltaic-green roof") ) &
                        (raw_data["Base case roof"] == "black roof") &
                        (raw_data["Climate"] == "Cfb") &
                        (raw_data["Continent"] == "Europe") &
                        (raw_data["Unusable monetary value"] != "x") &
                        ((raw_data["Item"] == "Urban heat island effect mitigation") |
                        (raw_data["Item"] == "Water runoff quality increase") |
                        (raw_data["Item"] == "Urban noise reduction") |
                        (raw_data["Item"] == "Biodiversity enhancement") |
                        (raw_data["Item"] == "Energy consumption reduction (heating and cooling)") |
                        (raw_data["Item"] == "Sound insulation") |
                        (raw_data["Item"] == "Aesthetics increase") |
                        (raw_data["Item"] == "Replacement and disposal of green roof") |
                        (raw_data["Item"] == "Installation of green roof (net)") |
                        (raw_data["Item"] == "Longevity increase") |
                        (raw_data["Item"] == "Fire risk reduction") |
                        (raw_data["Item"] == "Maintenance of green roof (net)") |
                        (raw_data["Item"] == "Air quality enhancement") |
                        (raw_data["Item"] == "CO2 emission reduction") |
                        (raw_data["Item"] == "Stormwater management") |
                        (raw_data["Item"] == "Air pollution from green roof production") |
                        (raw_data["Item"] == "CO2 emissions from green roof production") |
                        (raw_data["Item"] == "CO2 uptake") |
                        (raw_data["Item"] == "Electricity generation") |
                        (raw_data["Item"] == "Water runoff quality increase") |
                        (raw_data["Item"] == "Local area's aesthetics increase") |
                        (raw_data["Item"] == "Installation of PV panels"))]

local_items = local_items[["Item","Item type", "Actual year(s) at which the item is accounted", "Adjusted Monetary value [EU27 2020 €/m2]"]]

local_costs = local_items[ (local_items["Item type"]=="cost") ]
local_benefits = local_items[ (local_items["Item type"]=="benefit") ]
display(local_costs)
display(local_benefits)
# Out:
#                                  Item Item type  \
# 159  Installation of green roof (net)      cost
# 160   Maintenance of green roof (net)      cost
# 161  Installation of green roof (net)      cost
# 162  Installation of green roof (net)      cost
# 163   Maintenance of green roof (net)      cost
# 164   Maintenance of green roof (net)      cost
# 322  Installation of green roof (net)      cost
# 323  Installation of green roof (net)      cost
# 324  Installation of green roof (net)      cost
# 325  Installation of green roof (net)      cost
# 326  Installation of green roof (net)      cost
# 327  Installation of green roof (net)      cost
# 328  Installation of green roof (net)      cost
# 329  Installation of green roof (net)      cost
# 330  Installation of green roof (net)      cost
# 331  Installation of green roof (net)      cost
# 372   Maintenance of green roof (net)      cost
# 373   Maintenance of green roof (net)      cost
# 374   Maintenance of green roof (net)      cost
# 375   Maintenance of green roof (net)      cost
# 376   Maintenance of green roof (net)      cost
# 382   Maintenance of green roof (net)      cost
# 383   Maintenance of green roof (net)      cost
# 384   Maintenance of green roof (net)      cost
# 385   Maintenance of green roof (net)      cost
# 386   Maintenance of green roof (net)      cost
# 520  Installation of green roof (net)      cost
#
#     Actual year(s) at which the item is accounted  \
# 159                                             0
# 160                                    every year
# 161                                             0
# 162                                             0
# 163                                    every year
# 164                                    every year
# 322                                             0
# 323                                             0
# 324                                             0
# 325                                             0
# 326                                             0
# 327                                             0
# 328                                             0
# 329                                             0
# 330                                             0
# 331                                             0
# 372                                    every year
# 373                                    every year
# 374                                    every year
# 375                                    every year
# 376                                    every year
# 382                                    every year
# 383                                    every year
# 384                                    every year
# 385                                    every year
# 386                                    every year
# 520                                             0
#
#      Adjusted Monetary value [EU27 2020 €/m2]
# 159                                 33.212560
# 160                                  1.082310
# 161                                 34.841625
# 162                                 31.583495
# 163                                  1.079255
# 164                                  1.085364
# 322                                 74.175124
# 323                                 92.718905
# 324                                 69.539179
# 325                                 74.175124
# 326                                 69.539179
# 327                                 77.708656
# 328                                 97.135820
# 329                                 72.851865
# 330                                 77.708656
# 331                                 72.851865
# 372                                  0.032510
# 373                                  0.496516
# 374                                  0.306382
# 375                                  0.406867
# 376                                  0.878754
# 382                                  0.058302
# 383                                  0.334766
# 384                                  0.228506
# 385                                  0.286808
# 386                                  0.569855
# 520                                 18.605990
#                                                   Item Item type  \
# 172                                   Sound insulation   benefit
# 173                                   Sound insulation   benefit
# 174                                   Sound insulation   benefit
# 175                                 Longevity increase   benefit
# 176                                 Longevity increase   benefit
# 177                                 Longevity increase   benefit
# 178                            Air quality enhancement   benefit
# 179                            Air quality enhancement   benefit
# 180                            Air quality enhancement   benefit
# 181                Urban heat island effect mitigation   benefit
# 182                Urban heat island effect mitigation   benefit
# 183                Urban heat island effect mitigation   benefit
# 184                             CO2 emission reduction   benefit
# 185                             CO2 emission reduction   benefit
# 186                             CO2 emission reduction   benefit
# 187                      Water runoff quality increase   benefit
# 188                      Water runoff quality increase   benefit
# 189                      Water runoff quality increase   benefit
# 190                              Stormwater management   benefit
# 191                              Stormwater management   benefit
# 192                              Stormwater management   benefit
# 193                                Fire risk reduction   benefit
# 194                                Fire risk reduction   benefit
# 195                                Fire risk reduction   benefit
# 367  Energy consumption reduction (heating and cool...   benefit
# 368  Energy consumption reduction (heating and cool...   benefit
# 369  Energy consumption reduction (heating and cool...   benefit
# 370  Energy consumption reduction (heating and cool...   benefit
# 371  Energy consumption reduction (heating and cool...   benefit
# 377  Energy consumption reduction (heating and cool...   benefit
# 378  Energy consumption reduction (heating and cool...   benefit
# 379  Energy consumption reduction (heating and cool...   benefit
# 380  Energy consumption reduction (heating and cool...   benefit
# 381  Energy consumption reduction (heating and cool...   benefit
# 411  Energy consumption reduction (heating and cool...   benefit
# 412                              Stormwater management   benefit
# 413                                   Sound insulation   benefit
# 414                                 Longevity increase   benefit
# 415                            Air quality enhancement   benefit
# 416                                         CO2 uptake   benefit
# 524                              Stormwater management   benefit
# 528                                 Longevity increase   benefit
# 529                           Biodiversity enhancement   benefit
# 530                                         CO2 uptake   benefit
# 535  Energy consumption reduction (heating and cool...   benefit
# 603                                Aesthetics increase   benefit
# 800                              Stormwater management   benefit
# 801                              Stormwater management   benefit
# 802                              Stormwater management   benefit
# 803                              Stormwater management   benefit
# 804                              Stormwater management   benefit
# 805                              Stormwater management   benefit
#
#     Actual year(s) at which the item is accounted  \
# 172                                    every year
# 173                                    every year
# 174                                    every year
# 175                                    every year
# 176                                    every year
# 177                                    every year
# 178                                    every year
# 179                                    every year
# 180                                    every year
# 181                                    every year
# 182                                    every year
# 183                                    every year
# 184                                    every year
# 185                                    every year
# 186                                    every year
# 187                                    every year
# 188                                    every year
# 189                                    every year
# 190                                    every year
# 191                                    every year
# 192                                    every year
# 193                                    every year
# 194                                    every year
# 195                                    every year
# 367                                    every year
# 368                                    every year
# 369                                    every year
# 370                                    every year
# 371                                    every year
# 377                                    every year
# 378                                    every year
# 379                                    every year
# 380                                    every year
# 381                                    every year
# 411                                    every year
# 412                                    every year
# 413                                    every year
# 414                                    every year
# 415                                    every year
# 416                                    every year
# 524                                    every year
# 528                                    every year
# 529                                    every year
# 530                                    every year
# 535                                    every year
# 603                                             0
# 800                                    every year
# 801                                    every year
# 802                                    every year
# 803                                    every year
# 804                                    every year
# 805                                    every year
#
#      Adjusted Monetary value [EU27 2020 €/m2]
# 172                                  0.292214
# 173                                  0.277959
# 174                                  0.306468
# 175                                  7.343010
# 176                                  7.343010
# 177                                  7.343010
# 178                                  0.375703
# 179                                  0.012625
# 180                                  0.499919
# 181                                  0.000000
# 182                                  0.000000
# 183                                  0.000000
# 184                                  0.030545
# 185                                  0.020363
# 186                                  0.082471
# 187                                  0.308504
# 188                                  0.293232
# 189                                  0.323777
# 190                                  0.101817
# 191                                  0.096726
# 192                                  0.106907
# 193                                  0.000000
# 194                                  0.000000
# 195                                  0.000000
# 367                                  0.191119
# 368                                  0.441347
# 369                                  0.376327
# 370                                  0.407852
# 371                                  0.521145
# 377                                  0.078990
# 378                                  0.337587
# 379                                  0.278345
# 380                                  0.292450
# 381                                  0.409994
# 411                                  2.224229
# 412                                  0.540394
# 413                                  0.635087
# 414                                  0.889976
# 415                                  0.030853
# 416                                  0.002848
# 524                                  1.468943
# 528                                  2.307143
# 529                                  0.154169
# 530                                  0.003410
# 535                                  1.311184
# 603                                328.339910
# 800                                  0.893785
# 801                                  0.893785
# 802                                  0.891963
# 803                                  2.679685
# 804                                  0.893785
# 805                                  0.893785

# %%
# Visualize the years at which the costs and benefits need to be accounted in the CBA Model

global_costs.groupby("Item")["Actual year(s) at which the item is accounted"].agg(lambda x:x.value_counts().index[0])

global_benefits.groupby("Item")["Actual year(s) at which the item is accounted"].agg(lambda x:x.value_counts().index[0])
# Out:
# Item
# Aesthetics increase                                            0
# Air quality enhancement                               every year
# Biodiversity enhancement                              every year
# CO2 emission reduction                                every year
# CO2 uptake                                            every year
# Electricity generation                                every year
# Energy consumption reduction (heating and cooling)    every year
# Fire risk reduction                                   every year
# Local area's aesthetics increase                               0
# Longevity increase                                    every year
# Sound insulation                                      every year
# Stormwater management                                 every year
# Urban heat island effect mitigation                   every year
# Urban noise reduction                                 every year
# Water runoff quality increase                         every year
# Name: Actual year(s) at which the item is accounted, dtype: object

# %% [markdown]
# ## 1.1 Number of items for the global analysis

# %%
# determining the amount of datapoints within the range, so to gain insight into the representativeness of the using the range (i.e., max-min) for each 
# cost or benefit

def q1(Item):
    return Item.quantile(0.25)

def q3(Item):
    return Item.quantile(0.75)

def lower_whisker(Item):
     return max([Item.min(), q1(Item)-1.5*(q3(Item)-q1(Item)) ])


def upper_whisker(Item):
    return q3(Item)+1.5*(q3(Item)-q1(Item))
#     whisker_lim = q3(Item)+1.5*(q3(Item)-q1(Item))
#     upper_whisker = Item["Adjusted Monetary value [EU27 2020 €/m2]"].max()
#     values_df = Item.sort_values(by='Adjusted Monetary value [EU27 2020 €/m2]',ascending=True)
#     i = 1
    
#     while upper_whisker > whisker_lim:
#         upper_whisker = values_df.iloc[-(1+i)]
#         i +=1

#     return upper_whisker



def density(Item):
    if Item.max() - Item.min() == 0:
        return "one value only"
    return Item.nunique()/ ( Item.max() - Item.min() )

def spacing(Item):
    return ( Item.max() - Item.min() ) / Item.nunique()

def n_without_outliers(Item):
    """This function calculates the number of unique values recorded for each item (i.e., cost or benefit), which are not
    outliers"""
    values_to_count = []
    
    for number in Item:
        if ((number >= lower_whisker(Item)) & (number <= upper_whisker(Item))):
            values_to_count.append(number)
    #only unique values are counted, so the length of the set associated to the list, instead of the list is returned
    return len(set(values_to_count))
def average(Item):
    return Item.mean()

def density_without_outliers(Item):
    return n_without_outliers(Item) / ( upper_whisker(Item) - lower_whisker(Item) )

def spacing_without_outliers(Item):
    return ( upper_whisker(Item) - lower_whisker(Item) ) / n_without_outliers(Item)

def n_outliers(Item):
    values_to_count = []
    for number in Item:
        if (( number < lower_whisker(Item) ) | ( number > upper_whisker(Item) )):
            values_to_count.append(number)
            
    #only unique values are counted, so the length of the set associated to the list, instead of the list is returned
    return len(set(values_to_count))


f = {'Adjusted Monetary value [EU27 2020 €/m2]': ['nunique', average, 'min', q1, 'median', q3, 'max',spacing, n_without_outliers, spacing_without_outliers]}
gl_summary_costs = global_costs.groupby('Item').agg(f)

# drop one level of the Multi-level data structure, so to have 2D Pandas DataFrame
gl_summary_costs.columns = gl_summary_costs.columns.droplevel()

# Replace the spaces in the row indexes' names (i.e., the benefits' names) with an underscore, and delete parentheses,
# so to be able to use the benefit names as variables in the CBA Model
gl_summary_costs.index = gl_summary_costs.index.str.replace("(", "")
gl_summary_costs.index = gl_summary_costs.index.str.replace(")", "")
gl_summary_costs.index = gl_summary_costs.index.str.replace(" net", "")
gl_summary_costs.index = gl_summary_costs.index.str.replace(" ","_")

display(gl_summary_costs)

# do it again for benefits
gl_summary_benefits = global_benefits.groupby('Item').agg(f)

gl_summary_benefits.columns = gl_summary_benefits.columns.droplevel()
gl_summary_benefits.index = gl_summary_benefits.index.str.replace("(", "")
gl_summary_benefits.index = gl_summary_benefits.index.str.replace(")", "")
gl_summary_benefits.index = gl_summary_benefits.index.str.replace(" heating and cooling", "")
gl_summary_benefits.index = gl_summary_benefits.index.str.replace(" ","_")

display(gl_summary_benefits)
# Out:
#                                           nunique     average         min  \
# Item
# Air_pollution_from_green_roof_production        4    4.926380    0.000000
# CO2_emissions_from_green_roof_production        1    0.000000    0.000000
# Installation_of_PV_panels                       1  407.841419  407.841419
# Installation_of_green_roof                     32   61.376191    5.227100
# Maintenance_of_green_roof                      47    1.244133   -0.893647
# Replacement_and_disposal_of_green_roof          7   36.755779   19.766926
#
#                                                   q1      median          q3  \
# Item
# Air_pollution_from_green_roof_production    0.000000    0.000000    9.625077
# CO2_emissions_from_green_roof_production    0.000000    0.000000    0.000000
# Installation_of_PV_panels                 407.841419  407.841419  407.841419
# Installation_of_green_roof                 35.255851   62.299177   86.060229
# Maintenance_of_green_roof                   0.228506    0.920212    2.316177
# Replacement_and_disposal_of_green_roof     19.779366   25.041423   45.149490
#
#                                                  max    spacing  \
# Item
# Air_pollution_from_green_roof_production   15.689871   3.922468
# CO2_emissions_from_green_roof_production    0.000000   0.000000
# Installation_of_PV_panels                 407.841419   0.000000
# Installation_of_green_roof                116.815898   3.487150
# Maintenance_of_green_roof                   4.028232   0.104721
# Replacement_and_disposal_of_green_roof    103.855845  12.012703
#
#                                           n_without_outliers  \
# Item
# Air_pollution_from_green_roof_production                 4.0
# CO2_emissions_from_green_roof_production                 1.0
# Installation_of_PV_panels                                1.0
# Installation_of_green_roof                              32.0
# Maintenance_of_green_roof                               47.0
# Replacement_and_disposal_of_green_roof                   6.0
#
#                                           spacing_without_outliers
# Item
# Air_pollution_from_green_roof_production                  6.015673
# CO2_emissions_from_green_roof_production                  0.000000
# Installation_of_PV_panels                                 0.000000
# Installation_of_green_roof                                4.907491
# Maintenance_of_green_roof                                 0.134922
# Replacement_and_disposal_of_green_roof                   10.572958
#                                      nunique     average       min  \
# Item
# Aesthetics_increase                       19   91.539244  1.973705
# Air_quality_enhancement                   20    0.375100  0.000000
# Biodiversity_enhancement                   9    0.280780  0.000000
# CO2_emission_reduction                    16    0.411049 -0.028056
# CO2_uptake                                 9    0.447684  0.000000
# Electricity_generation                    18   11.522450  2.797891
# Energy_consumption_reduction              67    3.492932 -0.384476
# Fire_risk_reduction                        5    0.063330  0.000000
# Local_area's_aesthetics_increase           3  355.990747  0.000097
# Longevity_increase                        19    2.879076  0.000000
# Sound_insulation                          10    6.922846  0.277959
# Stormwater_management                     34   10.564153  0.002255
# Urban_heat_island_effect_mitigation        9    1.791571  0.000000
# Urban_noise_reduction                      2    2.234930  1.703389
# Water_runoff_quality_increase              4    0.085042  0.001244
#
#                                              q1      median          q3  \
# Item
# Aesthetics_increase                   39.906160   75.544018  135.475059
# Air_quality_enhancement                0.068790    0.132600    0.499919
# Biodiversity_enhancement               0.003468    0.140782    0.671752
# CO2_emission_reduction                 0.016522    0.127812    0.243155
# CO2_uptake                             0.000000    0.001230    0.024550
# Electricity_generation                 9.915276   10.688906   15.329948
# Energy_consumption_reduction           0.288924    0.807699    1.787248
# Fire_risk_reduction                    0.031100    0.074639    0.099519
# Local_area's_aesthetics_increase     125.143246  250.286396  533.986072
# Longevity_increase                     0.988657    1.998873    3.315625
# Sound_insulation                       1.336204    2.023187    4.911171
# Stormwater_management                  0.027868    0.075856    0.891963
# Urban_heat_island_effect_mitigation    0.000000    0.124399    0.124399
# Urban_noise_reduction                  2.301373    2.301373    2.301373
# Water_runoff_quality_increase          0.001244    0.001244    0.147238
#
#                                             max     spacing  \
# Item
# Aesthetics_increase                  328.339910   17.177169
# Air_quality_enhancement                1.481821    0.074091
# Biodiversity_enhancement               0.671752    0.074639
# CO2_emission_reduction                 3.399472    0.214221
# CO2_uptake                             5.687937    0.631993
# Electricity_generation                18.846151    0.891570
# Energy_consumption_reduction          54.027255    0.812115
# Fire_risk_reduction                    0.111959    0.022392
# Local_area's_aesthetics_increase     817.685748  272.561884
# Longevity_increase                     9.359783    0.492620
# Sound_insulation                      36.170080    3.589212
# Stormwater_management                340.581114   10.017025
# Urban_heat_island_effect_mitigation   25.094638    2.788293
# Urban_noise_reduction                  2.301373    0.298992
# Water_runoff_quality_increase          0.323777    0.080633
#
#                                      n_without_outliers  \
# Item
# Aesthetics_increase                                18.0
# Air_quality_enhancement                            17.0
# Biodiversity_enhancement                            9.0
# CO2_emission_reduction                             13.0
# CO2_uptake                                          7.0
# Electricity_generation                             18.0
# Energy_consumption_reduction                       60.0
# Fire_risk_reduction                                 5.0
# Local_area's_aesthetics_increase                    3.0
# Longevity_increase                                 16.0
# Sound_insulation                                    6.0
# Stormwater_management                              29.0
# Urban_heat_island_effect_mitigation                 4.0
# Urban_noise_reduction                               1.0
# Water_runoff_quality_increase                       4.0
#
#                                      spacing_without_outliers
# Item
# Aesthetics_increase                                 15.380817
# Air_quality_enhancement                              0.067448
# Biodiversity_enhancement                             0.186020
# CO2_emission_reduction                               0.047012
# CO2_uptake                                           0.008768
# Electricity_generation                               1.147448
# Energy_consumption_reduction                         0.073654
# Fire_risk_reduction                                  0.040430
# Local_area's_aesthetics_increase                   382.416738
# Longevity_increase                                   0.425380
# Sound_insulation                                     1.665944
# Stormwater_management                                0.075374
# Urban_heat_island_effect_mitigation                  0.077749
# Urban_noise_reduction                                0.000000
# Water_runoff_quality_increase                        0.091246

# %% [markdown]
# ## 1.2 Number of items for the local analysis

# %%
f = {'Adjusted Monetary value [EU27 2020 €/m2]': ['nunique', average, 'min', lower_whisker, q1, 'median', q3, upper_whisker, 'max', density, spacing, n_without_outliers, spacing_without_outliers]}
loc_summary_costs = local_costs.groupby('Item').agg(f)

# drop one level of the Multi-level data structure, so to have 2D Pandas DataFrame
loc_summary_costs.columns = loc_summary_costs.columns.droplevel()

# Replace the spaces in the row indexes' names (i.e., the benefits' names) with an underscore, and delete parentheses,
# so to be able to use the benefit names as variables in the CBA Model
loc_summary_costs.index = loc_summary_costs.index.str.replace("(", "")
loc_summary_costs.index = loc_summary_costs.index.str.replace(")", "")
loc_summary_costs.index = loc_summary_costs.index.str.replace(" net", "")
loc_summary_costs.index = loc_summary_costs.index.str.replace(" ","_")

display(loc_summary_costs)

# do it again for benefits
loc_summary_benefits = local_benefits.groupby('Item').agg(f)

loc_summary_benefits.columns = loc_summary_benefits.columns.droplevel()
loc_summary_benefits.index = loc_summary_benefits.index.str.replace("(", "")
loc_summary_benefits.index = loc_summary_benefits.index.str.replace(")", "")
loc_summary_benefits.index = loc_summary_benefits.index.str.replace(" heating and cooling", "")
loc_summary_benefits.index = loc_summary_benefits.index.str.replace(" ","_")

display(loc_summary_benefits)
# Out:
#                             nunique    average       min  lower_whisker  \
# Item
# Installation_of_green_roof       10  64.046289  18.60599       18.60599
# Maintenance_of_green_roof        13   0.526630   0.03251        0.03251
#
#                                    q1     median         q3  upper_whisker  \
# Item
# Installation_of_green_roof  43.516013  72.851865  76.825273     126.789162
# Maintenance_of_green_roof    0.286808   0.406867   0.878754       1.766673
#
#                                   max    density   spacing  \
# Item
# Installation_of_green_roof  97.135820   0.127340  7.852983
# Maintenance_of_green_roof    1.085364  12.347385  0.080989
#
#                             n_without_outliers  spacing_without_outliers
# Item
# Installation_of_green_roof                10.0                 10.818317
# Maintenance_of_green_roof                 13.0                  0.133397
#                                      nunique     average         min  \
# Item
# Aesthetics_increase                        1  328.339910  328.339910
# Air_quality_enhancement                    4    0.229775    0.012625
# Biodiversity_enhancement                   1    0.154169    0.154169
# CO2_emission_reduction                     3    0.044460    0.020363
# CO2_uptake                                 2    0.003129    0.002848
# Energy_consumption_reduction              12    0.572547    0.078990
# Fire_risk_reduction                        1    0.000000    0.000000
# Longevity_increase                         3    5.045230    0.889976
# Sound_insulation                           4    0.377932    0.277959
# Stormwater_management                      8    0.860143    0.096726
# Urban_heat_island_effect_mitigation        1    0.000000    0.000000
# Water_runoff_quality_increase              3    0.308504    0.293232
#
#                                      lower_whisker          q1      median  \
# Item
# Aesthetics_increase                     328.339910  328.339910  328.339910
# Air_quality_enhancement                   0.012625    0.026296    0.203278
# Biodiversity_enhancement                  0.154169    0.154169    0.154169
# CO2_emission_reduction                    0.020363    0.025454    0.030545
# CO2_uptake                                0.002848    0.002988    0.003129
# Energy_consumption_reduction              0.078990    0.288924    0.392090
# Fire_risk_reduction                       0.000000    0.000000    0.000000
# Longevity_increase                        0.889976    2.307143    7.343010
# Sound_insulation                          0.277959    0.288650    0.299341
# Stormwater_management                     0.096726    0.323650    0.893785
# Urban_heat_island_effect_mitigation       0.000000    0.000000    0.000000
# Water_runoff_quality_increase             0.293232    0.300868    0.308504
#
#                                              q3  upper_whisker         max  \
# Item
# Aesthetics_increase                  328.339910     328.339910  328.339910
# Air_quality_enhancement                0.406757       0.977449    0.499919
# Biodiversity_enhancement               0.154169       0.154169    0.154169
# CO2_emission_reduction                 0.056508       0.103089    0.082471
# CO2_uptake                             0.003269       0.003691    0.003410
# Energy_consumption_reduction           0.461297       0.719856    2.224229
# Fire_risk_reduction                    0.000000       0.000000    0.000000
# Longevity_increase                     7.343010      14.896811    7.343010
# Sound_insulation                       0.388623       0.538582    0.635087
# Stormwater_management                  0.893785       1.748987    2.679685
# Urban_heat_island_effect_mitigation    0.000000       0.000000    0.000000
# Water_runoff_quality_increase          0.316140       0.339049    0.323777
#
#                                             density   spacing  \
# Item
# Aesthetics_increase                  one value only  0.000000
# Air_quality_enhancement                      8.2086  0.121824
# Biodiversity_enhancement             one value only  0.000000
# CO2_emission_reduction                      48.3029  0.020703
# CO2_uptake                                  3558.42  0.000281
# Energy_consumption_reduction                5.59378  0.178770
# Fire_risk_reduction                  one value only  0.000000
# Longevity_increase                         0.464898  2.151011
# Sound_insulation                            11.2005  0.089282
# Stormwater_management                       3.09722  0.322870
# Urban_heat_island_effect_mitigation  one value only  0.000000
# Water_runoff_quality_increase               98.2159  0.010182
#
#                                      n_without_outliers  \
# Item
# Aesthetics_increase                                 1.0
# Air_quality_enhancement                             4.0
# Biodiversity_enhancement                            1.0
# CO2_emission_reduction                              3.0
# CO2_uptake                                          2.0
# Energy_consumption_reduction                       10.0
# Fire_risk_reduction                                 1.0
# Longevity_increase                                  3.0
# Sound_insulation                                    3.0
# Stormwater_management                               7.0
# Urban_heat_island_effect_mitigation                 1.0
# Water_runoff_quality_increase                       3.0
#
#                                      spacing_without_outliers
# Item
# Aesthetics_increase                                  0.000000
# Air_quality_enhancement                              0.241206
# Biodiversity_enhancement                             0.000000
# CO2_emission_reduction                               0.027575
# CO2_uptake                                           0.000422
# Energy_consumption_reduction                         0.064087
# Fire_risk_reduction                                  0.000000
# Longevity_increase                                   4.668945
# Sound_insulation                                     0.086874
# Stormwater_management                                0.236037
# Urban_heat_island_effect_mitigation                  0.000000
# Water_runoff_quality_increase                        0.015272

# %% [markdown]
# # 2. Visualization of Costs

# %%
# plot all one-off costs (occurring one time only)

gl_costs_fig = global_costs[(global_costs["Item"]!="Installation of PV panels") &
                            (global_costs["Item"]!="Maintenance of green roof (net)")]
loc_costs_fig = local_costs[(local_costs["Item"]!="Installation of PV panels") &
                            (local_costs["Item"]!="Maintenance of green roof (net)")]



# Add global analysis' boxplot
box = gl_costs_fig.boxplot(column="Adjusted Monetary value [EU27 2020 €/m2]", by=["Item"], 
                      figsize=(8,6), 
                      fontsize=14, 
                      showfliers=True,
                      rot=0,
                      vert=False,

                      return_type= "both")
[whiskers.get_xdata() for whiskers in box[0].lines["whiskers"]]
# Out:
# [array([0., 0.]),
#  array([ 9.62507652, 15.68987092]),
#  array([0., 0.]),
#  array([0., 0.]),
#  array([35.25585053,  5.22709987]),
#  array([ 86.06022907, 116.81589831]),
#  array([19.77936574, 19.76692589]),
#  array([45.14949014, 58.65354226])]

# %%
# plot all one-off costs (occurring one time only)

gl_costs_fig = global_costs[(global_costs["Item"]!="Installation of PV panels") &
                            (global_costs["Item"]!="Maintenance of green roof (net)")]
loc_costs_fig = local_costs[(local_costs["Item"]!="Installation of PV panels") &
                            (local_costs["Item"]!="Maintenance of green roof (net)")]



# Add global analysis' boxplot
box_gl = gl_costs_fig.boxplot(column="Adjusted Monetary value [EU27 2020 €/m2]", by=["Item"], 
                      figsize=(8,6), 
                      fontsize=14, 
                      showfliers=True,
                      rot=0,
                      vert=False,
                      positions = [1,2,3.2,4],
                      return_type= "both",
                      color=dict(boxes='#1f77b4', whiskers='#1f77b4', medians='g', caps='black'))

# Add global analysis' datapoints
for n,item in enumerate( np.sort(gl_costs_fig["Item"].unique()) ):
    x = gl_costs_fig["Adjusted Monetary value [EU27 2020 €/m2]"][gl_costs_fig["Item"]==item]
    
    # Add some random "jitter" to the y-axis
    if n == 2: #in the case of the "installation of green roofs (global)" increase the height
        n = 2.2
    
    y = np.random.normal(n+1, 0.01, size=len(x))
    plt.plot(x, y, 'orange', marker="o", linestyle="None", alpha=0.5)
    

# Add local analysis' boxplot and datapoints
for n,item in enumerate( np.sort(loc_costs_fig["Item"].unique()) ):  #There is only the installation of green roof item
    x = loc_costs_fig["Adjusted Monetary value [EU27 2020 €/m2]"][loc_costs_fig["Item"]==item]
    
    # Add some random "jitter" to the y-axis
    y = np.random.normal(2.65, 0.02, size=len(x))
    
    plt.plot(x, y, 'green', marker="o", linestyle="None", alpha=0.5)
    box_loc = plt.boxplot(x, positions = [2.65], vert=False, manage_xticks=False, patch_artist=True,
                widths=0.42,
                boxprops=dict(facecolor="None", color='#1f77b4'),
                capprops=dict(color="black"),
                whiskerprops=dict(color='#1f77b4'),
                flierprops=dict(color="white", markeredgecolor="black"),
                medianprops=dict(color="g"))
    
plt.yticks([1, 2, 2.65, 3.2, 4], ['Air pollution from green roof production (global)',
                                 'CO2 emission from green roof production (global)',
                                 'Installation of green roof (local)',
                                 'Installation of green roof (global)',
                                 'Replacement and disposal of green roof (global)'])
plt.xlabel('Monetary value [EU27 2020 €/m2]', fontsize=14, labelpad=15)
plt.title('', fontsize=15)
plt.ylim(0.5,4.5);

plt.savefig("Figures/One-off costs",dpi=300, bbox_inches = "tight")

# Whiskers' values
print("global boxplots' whiskers: ",[whiskers.get_xdata() for whiskers in box_gl[0].lines["whiskers"]])
print("local boxplots' whiskers: ",[whiskers.get_xdata() for whiskers in box_loc["whiskers"]])
# Out:
# global boxplots' whiskers:  [array([0., 0.]), array([ 9.62507652, 15.68987092]), array([0., 0.]), array([0., 0.]), array([35.25585053,  5.22709987]), array([ 86.06022907, 116.81589831]), array([19.77936574, 19.76692589]), array([45.14949014, 58.65354226])]
# local boxplots' whiskers:  [array([43.51601323, 18.60599023]), array([76.82527269, 97.13581957])]

# %%
# plot maintenance cost (which is a yearly value)
gl_maintenance = global_costs[global_costs["Item"]=="Maintenance of green roof (net)"]["Adjusted Monetary value [EU27 2020 €/m2]"]
loc_maintenance = local_costs[local_costs["Item"]=="Maintenance of green roof (net)"]["Adjusted Monetary value [EU27 2020 €/m2]"]

maintenance_df = pd.DataFrame({'Maintenance cost (local)': loc_maintenance, 'Maintenance cost (global)': gl_maintenance})

_, box = maintenance_df.boxplot(figsize=(8,3), 
                               fontsize=14, 
                               showfliers=True,
                               rot=0,
                               vert=False,
                               widths = 0.58,
                               return_type = "both",
                               color=dict(boxes='#1f77b4', whiskers='#1f77b4', medians='g', caps='black'))


# Add datapoints

# Add some random "jitter" to the y-axis
y_global = np.random.normal(2, 0.01, size=len(gl_maintenance))
y_local = np.random.normal(1, 0.01, size=len(loc_maintenance))

#plot the datapoints
plt.plot(gl_maintenance, y_global, 'orange', marker="o", linestyle="None", alpha=0.5)
plt.plot(loc_maintenance, y_local, 'green', marker="o", linestyle="None", alpha=0.5)

    
plt.xlabel('Monetary value [EU27 2020 €/m2/year]', fontsize=14, labelpad=15)
plt.title('', fontsize=15);

plt.savefig("Figures/Maintenance cost",dpi=300, bbox_inches = "tight")

# whiskers' values
[whiskers.get_xdata() for whiskers in box["whiskers"]]
# Out:
# [array([0.28680797, 0.03250996]),
#  array([0.87875407, 1.08536447]),
#  array([ 0.22850602, -0.89364729]),
#  array([2.31617673, 4.02823162])]

# %% [markdown]
# # 3. Visualization of Benefits

# %% [markdown]
# ## 3.1 Comparison between air quality enhancement, CO2 emission reduction, and CO2 uptake

# %%
gl_air_quality = global_benefits[(global_benefits["Item"]=="Air quality enhancement") |
                                  (global_benefits["Item"]=="CO2 emission reduction") |
                                  (global_benefits["Item"]=="CO2 uptake") ]
loc_air_quality = local_benefits[(local_benefits["Item"]=="Air quality enhancement") |
                                  (local_benefits["Item"]=="CO2 emission reduction") |
                                  (local_benefits["Item"]=="CO2 uptake") ]



box_gl = gl_air_quality.boxplot(column="Adjusted Monetary value [EU27 2020 €/m2]", by=["Item"], 
                           figsize=(11,7.5), 
                           fontsize=15, 
                           showfliers=True,
                           vert=False,
                           widths = 0.3,
                           positions=[1.35, 2.35, 3.35],
                           return_type= "both",
                           color=dict(boxes='#1f77b4', whiskers='#1f77b4', medians='g', caps='black'))

# Add global analysis' datapoints
for n,item in enumerate( np.sort(gl_air_quality["Item"].unique()) ):
    x = gl_air_quality["Adjusted Monetary value [EU27 2020 €/m2]"][gl_air_quality["Item"]==item]
    
    # set the plot's position
    n += 0.35
    
    # Add some random "jitter" to the y-axis
    y = np.random.normal(n+1, 0.01, size=len(x))
    plt.plot(x, y, 'orange', marker="o", linestyle="None", alpha=0.5)

    
# Add local analysis boxplot and datapoints
for n,item in enumerate( np.sort(loc_air_quality["Item"].unique()) ):  #There is only the aesthetics increase
    x = loc_air_quality["Adjusted Monetary value [EU27 2020 €/m2]"][loc_air_quality["Item"]==item]
    
    # Add some random "jitter" to the y-axis
    y = np.random.normal(n+.93, 0.02, size=len(x))
    
    plt.plot(x, y, 'green', marker="o", linestyle="None", alpha=0.5)
    box_loc = plt.boxplot(x, positions = [n+.93], vert=False, manage_xticks=False, patch_artist=True,
                widths=0.3,
                boxprops=dict(facecolor="None", color='#1f77b4'),
                capprops=dict(color="black"),
                whiskerprops=dict(color='#1f77b4'),
                flierprops=dict(color="white", markeredgecolor="black"),
                medianprops=dict(color="g"))
    
    
plt.yticks([0.93, 1.35, 1.93, 2.35, 2.93, 3.35], 
           ["Air quality enhancement (local)",
           "Air quality enhancement (global)",
           "CO2 emission reduction (local)",
           "CO2 emission reduction (global)",
           "CO2 uptake (local)",
           "CO2 uptake (global)"],
           fontsize=15)        


plt.xlabel('Monetary value [EU27 2020 €/m2/year]', fontsize=16, labelpad=15)
plt.ylim(0.5,3.6);
plt.title('')
plt.savefig("Figures/Air quality",dpi=300, bbox_inches = "tight")


# whiskers' values
print("global boxplots' whiskers: ",[whiskers.get_xdata() for whiskers in box_gl[0].lines["whiskers"]])
print("local boxplots' whiskers: ",[whiskers.get_xdata() for whiskers in box_loc["whiskers"]])
# Out:
# global boxplots' whiskers:  [array([0.06879006, 0.        ]), array([0.49991928, 1.08465183]), array([ 0.01652151, -0.02805637]), array([0.24315519, 0.37512404]), array([0., 0.]), array([0.02455038, 0.03952631])]
# local boxplots' whiskers:  [array([0.00298844, 0.00284792]), array([0.00326946, 0.00340997])]

# %%
#Zoom of the previous figure

gl_air_quality = global_benefits[(global_benefits["Item"]=="Air quality enhancement") |
                                  (global_benefits["Item"]=="CO2 emission reduction") |
                                  (global_benefits["Item"]=="CO2 uptake") ]
loc_air_quality = local_benefits[(local_benefits["Item"]=="Air quality enhancement") |
                                  (local_benefits["Item"]=="CO2 emission reduction") |
                                  (local_benefits["Item"]=="CO2 uptake") ]



gl_air_quality.boxplot(column="Adjusted Monetary value [EU27 2020 €/m2]", by=["Item"], 
                           figsize=(11,7.5), 
                           fontsize=15, 
                           showfliers=True,
                           vert=False,
                           widths = 0.3,
                           positions=[1.35, 2.35, 3.35],
                           color=dict(boxes='#1f77b4', whiskers='#1f77b4', medians='g', caps='black'))

# Add global analysis' datapoints
for n,item in enumerate( np.sort(gl_air_quality["Item"].unique()) ):
    x = gl_air_quality["Adjusted Monetary value [EU27 2020 €/m2]"][gl_air_quality["Item"]==item]
    
    # set the plot's position
    n += 0.35
    
    # Add some random "jitter" to the y-axis
    y = np.random.normal(n+1, 0.01, size=len(x))
    plt.plot(x, y, 'orange', marker="o", linestyle="None", alpha=0.5)

    
# Add local analysis boxplot and datapoints
for n,item in enumerate( np.sort(loc_air_quality["Item"].unique()) ):  #There is only the aesthetics increase
    x = loc_air_quality["Adjusted Monetary value [EU27 2020 €/m2]"][loc_air_quality["Item"]==item]
    
    # Add some random "jitter" to the y-axis
    y = np.random.normal(n+.93, 0.02, size=len(x))
    
    plt.plot(x, y, 'green', marker="o", linestyle="None", alpha=0.5)
    plt.boxplot(x, positions = [n+.93], vert=False, manage_xticks=False, patch_artist=True,
                widths=0.3,
                boxprops=dict(facecolor="None", color='#1f77b4'),
                capprops=dict(color="black"),
                whiskerprops=dict(color='#1f77b4'),
                flierprops=dict(color="white", markeredgecolor="black"),
                medianprops=dict(color="g"))
    
    
plt.yticks([0.93, 1.35, 1.93, 2.35, 2.93, 3.35], 
           ["Air quality enhancement (local)",
           "Air quality enhancement (global)",
           "CO2 emission reduction (local)",
           "CO2 emission reduction (global)",
           "CO2 uptake (local)",
           "CO2 uptake (global)"],
           fontsize=15)        


plt.xlabel('Monetary value [EU27 2020 €/m2/year]', fontsize=16, labelpad=15)
plt.title('')
plt.xlim(-.07,1.09);
plt.ylim(0.5,3.6);
plt.savefig("Figures/Air quality - zoom",dpi=300, bbox_inches = "tight")

# %% [markdown]
# ## 3.2 Sound insulation

# %%
gl_sound = global_benefits[(global_benefits["Item"]=="Sound insulation")]["Adjusted Monetary value [EU27 2020 €/m2]"]
loc_sound = local_benefits[local_benefits["Item"]=="Sound insulation"]["Adjusted Monetary value [EU27 2020 €/m2]"]

sound_df = pd.DataFrame({'Sound insulation (local)': loc_sound, 'Sound insulation (global)': gl_sound})

_, box = sound_df.boxplot(figsize=(8,2), 
                 fontsize=14, 
                 showfliers=True,
                 rot=0,
                 vert=False,
                 widths = 0.75,
                 return_type="both",
                 color=dict(boxes='#1f77b4', whiskers='#1f77b4', medians='g', caps='black'))


# Add datapoints

# Add some random "jitter" to the y-axis
y_global = np.random.normal(2, 0.01, size=len(gl_sound))
y_local = np.random.normal(1, 0.01, size=len(loc_sound))

#plot the datapoints
plt.plot(gl_sound, y_global, 'orange', marker="o", linestyle="None", alpha=0.5)
plt.plot(loc_sound, y_local, 'green', marker="o", linestyle="None", alpha=0.5)

plt.xlabel('Monetary value [EU27 2020 €/m2/year]', fontsize=14)
plt.title('', fontsize=15)
plt.savefig("Figures/Sound",dpi=300, bbox_inches = "tight")

print("boxplots' whiskers: ",[whiskers.get_xdata() for whiskers in box["whiskers"]])
# Out:
# boxplots' whiskers:  [array([0.28864993, 0.27795919]), array([0.38862264, 0.38862264]), array([1.33620382, 0.27795919]), array([4.91117082, 4.91117082])]

# %%
gl_sound = global_benefits[(global_benefits["Item"]=="Sound insulation")]["Adjusted Monetary value [EU27 2020 €/m2]"]
loc_sound = local_benefits[local_benefits["Item"]=="Sound insulation"]["Adjusted Monetary value [EU27 2020 €/m2]"]

sound_df = pd.DataFrame({'Sound insulation (local)': loc_sound, 'Sound insulation (global)': gl_sound})

sound_df.boxplot(figsize=(8,2), 
                 fontsize=14, 
                 showfliers=True,
                 rot=0,
                 vert=False,
                 widths = 0.75,
                 color=dict(boxes='#1f77b4', whiskers='#1f77b4', medians='g', caps='black'))


# Add datapoints

# Add some random "jitter" to the y-axis
y_global = np.random.normal(2, 0.01, size=len(gl_sound))
y_local = np.random.normal(1, 0.01, size=len(loc_sound))

#plot the datapoints
plt.plot(gl_sound, y_global, 'orange', marker="o", linestyle="None", alpha=0.5)
plt.plot(loc_sound, y_local, 'green', marker="o", linestyle="None", alpha=0.5)

plt.xlabel('Monetary value [EU27 2020 €/m2/year]', fontsize=14)
plt.title('', fontsize=15)
plt.xlim(0,5)

plt.savefig("Figures/Sound - zoom",dpi=300, bbox_inches = "tight")

# %%
# Exclude case-studies' results that applied hedonic pricing to all floors instead of the highest (Almeida et al.) and 
# non least-cost options using the replacement cost method (Madyìhdiyar et al.). There are the monetary values higher than 10 €/m2 as
# it can be seen in the csv file.

gl_sound = global_benefits[(global_benefits["Item"]=="Sound insulation") &
               (global_benefits["Adjusted Monetary value [EU27 2020 €/m2]"] < 10)]["Adjusted Monetary value [EU27 2020 €/m2]"] 

loc_sound = local_benefits[local_benefits["Item"]=="Sound insulation"]["Adjusted Monetary value [EU27 2020 €/m2]"]

sound_df = pd.DataFrame({'Sound insulation (local)': loc_sound, 'Sound insulation (global)': gl_sound})

_, box = sound_df.boxplot(figsize=(8,2), 
                 fontsize=14, 
                 showfliers=True,
                 rot=0,
                 vert=False,
                 widths = 0.75,
                 return_type="both",
                 color=dict(boxes='#1f77b4', whiskers='#1f77b4', medians='g', caps='black'))


# Add datapoints

# Add some random "jitter" to the y-axis
y_global = np.random.normal(2, 0.01, size=len(gl_sound))
y_local = np.random.normal(1, 0.01, size=len(loc_sound))

#plot the datapoints
plt.plot(gl_sound, y_global, 'orange', marker="o", linestyle="None", alpha=0.5)
plt.plot(loc_sound, y_local, 'green', marker="o", linestyle="None", alpha=0.5)

plt.xlabel('Monetary value [EU27 2020 €/m2/year]', fontsize=14)
plt.title('', fontsize=15)
plt.savefig("Figures/Sound - correction",dpi=300, bbox_inches = "tight")

print("boxplots' whiskers: ",[whiskers.get_xdata() for whiskers in box["whiskers"]])
# Out:
# boxplots' whiskers:  [array([0.28864993, 0.27795919]), array([0.38862264, 0.38862264]), array([0.55293225, 0.27795919]), array([2.47646367, 2.47646367])]

# %% [markdown]
# ## 3.3 Aesthetics increase

# %%
# Plot the Aesthetics increase benefit separately, since it has a different unit of measure

gl_aesthetics = global_benefits[(global_benefits["Item"]=="Aesthetics increase")]["Adjusted Monetary value [EU27 2020 €/m2]"]
loc_aesthetics = local_benefits[local_benefits["Item"]=="Aesthetics increase"]["Adjusted Monetary value [EU27 2020 €/m2]"]

aesthetics_df = pd.DataFrame({'Aesthetics increase (local)': loc_aesthetics, 'Aesthetics increase (global)': gl_aesthetics})

f = aesthetics_df.boxplot(figsize=(8,2), 
                          fontsize=14, 
                          showfliers=True,
                          rot=0,
                          vert=False,
                          widths = 0.75,
                          color=dict(boxes='#1f77b4', whiskers='#1f77b4', medians='g', caps='black'))

# Add datapoints

# Add some random "jitter" to the y-axis
y_global = np.random.normal(2, 0.01, size=len(gl_aesthetics))
y_local = np.random.normal(1, 0.01, size=len(loc_aesthetics))

#plot the datapoints
plt.plot(gl_aesthetics, y_global, 'orange', marker="o", linestyle="None", alpha=0.5)
plt.plot(loc_aesthetics, y_local, 'green', marker="o", linestyle="None", alpha=0.5)

plt.xlabel('Monetary value [EU27 2020 €/m2]', fontsize=14)
plt.title('', fontsize=15)

plt.savefig("Figures/Aesthetics",dpi=300, bbox_inches = "tight")

# %%
# Plot the Aesthetics increase without Bianchini and Hewage's results

gl_aesthetics = global_benefits[(global_benefits["Item"]=="Aesthetics increase") & 
                (global_benefits["Adjusted Monetary value [EU27 2020 €/m2]"]>7)]["Adjusted Monetary value [EU27 2020 €/m2]"]
loc_aesthetics = local_benefits[local_benefits["Item"]=="Aesthetics increase"]["Adjusted Monetary value [EU27 2020 €/m2]"]

aesthetics_df = pd.DataFrame({'Aesthetics increase (local)': loc_aesthetics, 'Aesthetics increase (global)': gl_aesthetics})

f = aesthetics_df.boxplot(figsize=(8,2), 
                          fontsize=14, 
                          showfliers=True,
                          rot=0,
                          vert=False,
                          widths = 0.75,
                          color=dict(boxes='#1f77b4', whiskers='#1f77b4', medians='g', caps='black'))

# Add datapoints

# Add some random "jitter" to the y-axis
y_global = np.random.normal(2, 0.01, size=len(gl_aesthetics))
y_local = np.random.normal(1, 0.01, size=len(loc_aesthetics))

#plot the datapoints
plt.plot(gl_aesthetics, y_global, 'orange', marker="o", linestyle="None", alpha=0.5)
plt.plot(loc_aesthetics, y_local, 'green', marker="o", linestyle="None", alpha=0.5)

plt.xlabel('Monetary value [EU27 2020 €/m2]', fontsize=14)
plt.title('', fontsize=15)
plt.xlim(-15,34)

plt.savefig("Figures/Aesthetics - correction",dpi=300, bbox_inches = "tight")

# %% [markdown]
# ## 3.4 Stormwater management

# %%
gl_stormwater = global_benefits[(global_benefits["Item"]=="Stormwater management")]["Adjusted Monetary value [EU27 2020 €/m2]"]
loc_stormwater = local_benefits[(local_benefits["Item"]=="Stormwater management")]["Adjusted Monetary value [EU27 2020 €/m2]"]

stormwater_df = pd.DataFrame({'Stormwater management (local)': loc_stormwater, 'Stormwater management (global)': gl_stormwater})

_, box = stormwater_df.boxplot(figsize=(8,3), 
                               fontsize=14, 
                               showfliers=True,
                               rot=0,
                               vert=False,
                               widths = 0.58,
                               return_type="both",
                               color=dict(boxes='#1f77b4', whiskers='#1f77b4', medians='g', caps='black'))


# Add datapoints

# Add some random "jitter" to the y-axis
y_global = np.random.normal(2, 0.01, size=len(gl_stormwater))
y_local = np.random.normal(1, 0.01, size=len(loc_stormwater))

#plot the datapoints
plt.plot(gl_stormwater, y_global, 'orange', marker="o", linestyle="None", alpha=0.5)
plt.plot(loc_stormwater, y_local, 'green', marker="o", linestyle="None", alpha=0.5)

    
plt.xlabel('Monetary value [EU27 2020 €/m2/year]', fontsize=14, labelpad=15)
plt.title('', fontsize=15);

plt.savefig("Figures/Stormwater",dpi=300, bbox_inches = "tight")

# whiskers' values (the first numbers are the local boxplot's values)
[whiskers.get_xdata() for whiskers in box["whiskers"]]
# Out:
# [array([0.32365048, 0.09672573]),
#  array([0.89378491, 1.46894293]),
#  array([0.02786823, 0.0022549 ]),
#  array([0.89196303, 1.46894293])]

# %%
gl_stormwater = global_benefits[(global_benefits["Item"]=="Stormwater management")]["Adjusted Monetary value [EU27 2020 €/m2]"]
loc_stormwater = local_benefits[(local_benefits["Item"]=="Stormwater management")]["Adjusted Monetary value [EU27 2020 €/m2]"]

stormwater_df = pd.DataFrame({'Stormwater management (local)': loc_stormwater, 'Stormwater management (global)': gl_stormwater})

box = stormwater_df.boxplot(figsize=(8,3), 
                               fontsize=14, 
                               showfliers=True,
                               rot=0,
                               vert=False,
                               widths = 0.58,
                               color=dict(boxes='#1f77b4', whiskers='#1f77b4', medians='g', caps='black'))


# Add datapoints

# Add some random "jitter" to the y-axis
y_global = np.random.normal(2, 0.01, size=len(gl_stormwater))
y_local = np.random.normal(1, 0.01, size=len(loc_stormwater))

#plot the datapoints
plt.plot(gl_stormwater, y_global, 'orange', marker="o", linestyle="None", alpha=0.5)
plt.plot(loc_stormwater, y_local, 'green', marker="o", linestyle="None", alpha=0.5)

plt.xlim(-.23,5.12)
plt.xlabel('Monetary value [EU27 2020 €/m2/year]', fontsize=14, labelpad=15)
plt.title('', fontsize=15);

plt.savefig("Figures/Stormwater - zoom",dpi=300, bbox_inches = "tight")

# %% [markdown]
# ## 3.5 Other benefits

# %%
global_benefits.Item.unique()
# Out:
# array(['Urban heat island effect mitigation',
#        'Water runoff quality increase', 'Urban noise reduction',
#        'Biodiversity enhancement',
#        'Energy consumption reduction (heating and cooling)',
#        'Sound insulation', 'Aesthetics increase', 'Longevity increase',
#        'Fire risk reduction', 'Air quality enhancement',
#        'CO2 emission reduction', 'Stormwater management', 'CO2 uptake',
#        'Electricity generation', "Local area's aesthetics increase"],
#       dtype=object)

# %%
#Overview of distributions of the yearly benefits

gl_benefits_overview = global_benefits[(global_benefits["Item"]=="Urban heat island effect mitigation") |
                                       (global_benefits["Item"]=="Water runoff quality increase") | 
                                       (global_benefits["Item"]=="Biodiversity enhancement") |
                                       (global_benefits["Item"]=="Energy consumption reduction (heating and cooling)") |
                                       (global_benefits["Item"]=="Longevity increase") |
                                       (global_benefits["Item"]=="Fire risk reduction") |
                                       (global_benefits["Item"]=="Stormwater management") |
                                       (global_benefits["Item"]=="Electricity generation")]
                                       
loc_benefits_overview = local_benefits[(local_benefits["Item"]=="Urban heat island effect mitigation") |
                                       (local_benefits["Item"]=="Water runoff quality increase") | 
                                       (local_benefits["Item"]=="Biodiversity enhancement") |
                                       (local_benefits["Item"]=="Energy consumption reduction (heating and cooling)") |
                                       (local_benefits["Item"]=="Longevity increase") |
                                       (local_benefits["Item"]=="Fire risk reduction") |
                                       (local_benefits["Item"]=="Stormwater management") |
                                       (local_benefits["Item"]=="Electricity generation")]

gl_boxplot_positions = range(1,9,1)
gl_benefits_overview.boxplot(column="Adjusted Monetary value [EU27 2020 €/m2]", by=["Item"], 
                            figsize=(11,14), 
                            fontsize=14, 
                            showfliers=True,
                            rot = 0,
                            vert=False,
                            widths = 0.5,
                            positions = gl_boxplot_positions,
                            color=dict(boxes='#1f77b4', whiskers='#1f77b4', medians='g', caps='black'))
                           
plt.xlabel('Monetary value [EU27 2020 €/m2/year]', fontsize=14, labelpad=15)
plt.title('', fontsize=15);

# %%
gl_benefits_overview = global_benefits[(global_benefits["Item"]=="Energy consumption reduction (heating and cooling)") |
                                       (global_benefits["Item"]=="Stormwater management") |
                                       (global_benefits["Item"]=="Electricity generation")]

loc_benefits_overview = local_benefits[(local_benefits["Item"]=="Urban heat island effect mitigation") |
                                       (local_benefits["Item"]=="Water runoff quality increase") | 
                                       (local_benefits["Item"]=="Biodiversity enhancement") |
                                       (local_benefits["Item"]=="Energy consumption reduction (heating and cooling)") |
                                       (local_benefits["Item"]=="Longevity increase") |
                                       (local_benefits["Item"]=="Fire risk reduction") |
                                       (local_benefits["Item"]=="Stormwater management") |
                                       (local_benefits["Item"]=="Electricity generation")]

# %% [markdown]
# ## Additional code

# %%
#Overview of distributions of the one-time benefits

gl_aesthetics = global_benefits[(global_benefits["Item"]=="Local area's aesthetics increase") |
                                    (global_benefits["Item"]=="Aesthetics increase")]
loc_aesthetics = local_benefits[(local_benefits["Item"]=="Local area's aesthetics increase") |
                                    (local_benefits["Item"]=="Aesthetics increase")]

# Add global analysis' boxplots
gl_aesthetics.boxplot(column="Adjusted Monetary value [EU27 2020 €/m2]", by=["Item"], 
                            figsize=(8,5), 
                            fontsize=14, 
                            showfliers=True,
                            rot = 0,
                            vert=False,
                            widths = 0.5,
                            positions=[1.2, 2],
                            color=dict(boxes='#1f77b4', whiskers='#1f77b4', medians='g', caps='black'))


# Add global analysis' datapoints
for n,item in enumerate( np.sort(gl_aesthetics["Item"].unique()) ):
    x = gl_aesthetics["Adjusted Monetary value [EU27 2020 €/m2]"][gl_aesthetics["Item"]==item]
    
    # Add some random "jitter" to the y-axis
    if n == 0: #in the case of the "Aesthetics increase (global)" increase the height
        n = 0.2
    
    y = np.random.normal(n+1, 0.01, size=len(x))
    plt.plot(x, y, 'orange', marker="o", linestyle="None", alpha=0.5)

    
    
# Add local analysis boxplot and datapoints

for n,item in enumerate( np.sort(loc_aesthetics["Item"].unique()) ):  #There is only the aesthetics increase
    x = loc_aesthetics["Adjusted Monetary value [EU27 2020 €/m2]"][loc_aesthetics["Item"]==item]
    
    # Add some random "jitter" to the y-axis
    y = np.random.normal(0.5, 0.02, size=len(x))
    
    plt.plot(x, y, 'green', marker="o", linestyle="None", alpha=0.5)
    plt.boxplot(x, positions = [0.5], vert=False, manage_xticks=False, patch_artist=True,
                widths=0.47,
                boxprops=dict(facecolor="None", color='#1f77b4'),
                capprops=dict(color="black"),
                whiskerprops=dict(color='#1f77b4'),
                flierprops=dict(color="white", markeredgecolor="black"),
                medianprops=dict(color="g"))
    
    
plt.yticks([0.5, 1.2, 2], ["Aesthetics increase (local)",
                           "Aesthetics increase (global)",
                           "Surrounding area's aesthetics increase (global)"])    
plt.xlabel('Monetary value [EU27 2020 €/m2]', fontsize=14, labelpad=15)
plt.title('', fontsize=15);
plt.ylim(-.1,2.5);

# %%
# When outliers are excluded from the analysis the distribution of benefit values is provided by the following figure.
# The number of values for each item (i.e., cost or benefit) is provided in the summary_benefits table calculated at the top
# of this document

benefits_data_without_area_aesth = benefits_data[(benefits_data["Item"]!="Local area's aesthetics increase") & 
                                                 (benefits_data["Item"]!="Aesthetics increase")
                                                ]

benefits_data_without_area_aesth.boxplot(column="Adjusted Monetary value [EU27 2019 €/m2]", by=["Item"], 
                                         figsize=(11,6), 
                                         fontsize=14, 
                                         showfliers=False,
                                         rot = 90,
                                         color=dict(boxes='#1f77b4', whiskers='#1f77b4', medians='g', caps='black'))
                           
plt.ylabel('Adjusted Monetary value [EU27 2019 €/m2/year]', fontsize=14)
plt.title('', fontsize=15);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-7630f1f816fe> in <module>()
#       3 # of this document
#       4
# ----> 5 benefits_data_without_area_aesth = benefits_data[(benefits_data["Item"]!="Local area's aesthetics increase") &
#       6                                                  (benefits_data["Item"]!="Aesthetics increase")
#       7                                                 ]
#
# NameError: name 'benefits_data' is not defined

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,6), sharey = False) # create 1x2 array of subplots
plt.title('', fontsize=15)
# plt.savefig("Figures/Air quality overlaps",dpi=300, bbox_inches = "tight")


air_quality_issues = cleaned_data[(cleaned_data["Item"]=="Air quality enhancement") |
                                  (cleaned_data["Item"]=="CO2 emission reduction") |
                                  (cleaned_data["Item"]=="CO2 uptake") ]
CO2_uptake = cleaned_data[cleaned_data["Item"]=="CO2 uptake"]


air_quality_issues.boxplot(column="Adjusted Monetary value [EU27 2019 €/m2]", by=["Item"], 
                           figsize=(15,6), 
                           fontsize=14, 
                           showfliers=True,
                           color=dict(boxes='#1f77b4', whiskers='#1f77b4', medians='g', caps='black'),
                           ax = axes[0])
axes[0].set(ylabel= "Adjusted Monetary value [EU27 2019 €/m2/year]")
                           


CO2_uptake.boxplot(column="Adjusted Monetary value [EU27 2019 €/m2]", by=["Item"], 
                           figsize=(3,6), 
                           fontsize=14, 
                           showfliers=True,
                           color=dict(boxes='#1f77b4', whiskers='#1f77b4', medians='g', caps='black'),
                           ax = axes[1])

# %% [markdown]
# ## 4. Time horizon of CBAs

# %%
# Load global analysis data
raw_CBA_data = pd.read_csv("Data/CBA parameters.csv")
raw_CBA_data
# Out:
#     Private discount rate (min) [%]  Private discount rate (max) [%]  \
# 0                              4.00                             4.00
# 1                               NaN                              NaN
# 2                              9.00                             9.00
# 3                              8.00                            15.00
# 4                               NaN                              NaN
# 5                               NaN                              NaN
# 6                              3.00                             3.00
# 7                               NaN                              NaN
# 8                              3.50                             3.50
# 9                               NaN                              NaN
# 10                             5.00                             5.00
# 11                              NaN                              NaN
# 12                             3.50                             6.00
# 13                             4.00                             9.00
# 14                              NaN                              NaN
# 15                              NaN                              NaN
# 16                              NaN                              NaN
# 17                             3.00                             3.00
# 18                              NaN                              NaN
# 19                              NaN                              NaN
# 20                             3.36                             3.36
# 21                             6.67                             6.67
# 22                             3.50                             6.00
# 23                              NaN                              NaN
# 24                              NaN                              NaN
# 25                              NaN                              NaN
# 26                              NaN                              NaN
# 27                             4.80                             4.80
# 28                              NaN                              NaN
# 29                              NaN                              NaN
#
#     Social discount rate (min) [%]  Social discount rate (max) [%]  \
# 0                             4.00                            4.00
# 1                              NaN                             NaN
# 2                             4.00                            4.00
# 3                              NaN                             NaN
# 4                             2.00                            8.00
# 5                              NaN                             NaN
# 6                              NaN                             NaN
# 7                              NaN                             NaN
# 8                              NaN                             NaN
# 9                              NaN                             NaN
# 10                             NaN                             NaN
# 11                            4.00                            4.00
# 12                            3.00                            3.50
# 13                            3.00                            3.00
# 14                             NaN                             NaN
# 15                            3.50                            3.50
# 16                            4.25                            4.25
# 17                            3.00                            3.00
# 18                            5.50                            5.50
# 19                            4.50                            4.50
# 20                            3.36                            3.36
# 21                            6.67                            6.67
# 22                            3.00                            3.50
# 23                            5.00                            5.00
# 24                             NaN                             NaN
# 25                             NaN                             NaN
# 26                            4.00                            4.00
# 27                            4.80                            4.80
# 28                             NaN                             NaN
# 29                             NaN                             NaN
#
#     Non-specified type of iscount rate (min) [%]  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            5.0
# 8                                            NaN
# 9                                            NaN
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
# 14                                           6.0
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
# 18                                           NaN
# 19                                           NaN
# 20                                           NaN
# 21                                           NaN
# 22                                           NaN
# 23                                           NaN
# 24                                           3.5
# 25                                           8.0
# 26                                           NaN
# 27                                           NaN
# 28                                           NaN
# 29                                           NaN
#
#     Non-specified type of discount rate (max) [%]  Time horizon [years]  \
# 0                                             NaN                    40
# 1                                             NaN                    20
# 2                                             NaN                    50
# 3                                             NaN                    50
# 4                                             NaN                    55
# 5                                             NaN                    40
# 6                                             NaN                    25
# 7                                             5.0                    40
# 8                                             NaN                    50
# 9                                             NaN                    10
# 10                                            NaN                    25
# 11                                            NaN                    50
# 12                                            NaN                    40
# 13                                            NaN                    40
# 14                                            7.0                    40
# 15                                            NaN                    50
# 16                                            NaN                    40
# 17                                            NaN                    50
# 18                                            NaN                    20
# 19                                            NaN                    20
# 20                                            NaN                    40
# 21                                            NaN                    40
# 22                                            NaN                    75
# 23                                            NaN                    30
# 24                                            7.0                    40
# 25                                            8.0                    20
# 26                                            NaN                    50
# 27                                            NaN                    40
# 28                                            NaN                    50
# 29                                            NaN                    40
#
#                  Authors  Year              Author and year  \
# 0        Carter & Keeler  2008       Carter & Keeler (2008)
# 1         Ascione et al.  2013        Ascione et al. (2013)
# 2       Claus & Rousseau  2012      Claus & Rousseau (2012)
# 3        Mahdiyar et al.  2016       Mahdiyar et al. (2016)
# 4     Bianchini & Hewage  2012    Bianchini & Hewage (2012)
# 5     Bianchini & Hewage  2012    Bianchini & Hewage (2012)
# 6                  McRae  2016                 McRae (2016)
# 7          Clark et al.   2008          Clark et al. (2008)
# 8       Perini & Rosasco  2016      Perini & Rosasco (2016)
# 9            Gwak et al.  2017           Gwak et al. (2017)
# 10        Statler et al.  2017        Statler et al. (2017)
# 11         Machac et al.  2016         Machac et al. (2016)
# 12          Berto et al.  2018          Berto et al. (2018)
# 13       Teotónio et al.  2018       Teotónio et al. (2018)
# 14            Niu et al.  2010            Niu et al. (2010)
# 15        Nordman et al.  2018        Nordman et al. (2018)
# 16            Peng & Jim  2015            Peng & Jim (2015)
# 17  Johnson & Geisendorf  2019  Johnson & Geisendorf (2019)
# 18            Shin & Kim  2018            Shin & Kim (2018)
# 19            Shin & Kim  2019            Shin & Kim (2019)
# 20          Silva et al.  2019          Silva et al. (2019)
# 21        Almeida et al.  2020        Almeida et al. (2020)
# 22          Berto et al.  2020          Berto et al. (2020)
# 23        Vincent et al.  2017        Vincent et al. (2017)
# 24        William et al.  2016        William et al. (2016)
# 25            Xin et al.  2021            Xin et al. (2021)
# 26            Yao et al.  2018            Yao et al. (2018)
# 27           Melo et al.  2020           Melo et al. (2020)
# 28           Melo et al.  2020           Melo et al. (2020)
# 29         Mullen et al.  2013         Mullen et al. (2013)
#
#                                                 Study  \
# 0   Life-cycle cost-benefit analysis of extensive ...
# 1   Green roofs in European climates. Are effectiv...
# 2   Public versus private incentives to invest in ...
# 3   Probabilistic private cost-benefit analysis fo...
# 4   Probabilistic social cost-benefit analysis for...
# 5   Probabilistic social cost-benefit analysis for...
# 6   Case study: A conservative approach to green r...
# 7   Green roof valuation: a probabilisitc economic...
# 8   Is greening the building envelope economically...
# 9   Optimal location selection for the installatio...
# 10  Optimizing angles of rooftop photovoltaics, ra...
# 11  Green and Blue Infrastructure: An Opportunity ...
# 12  Enhancing the environmental performance of ind...
# 13  Eco-solutions for urban environments regeneration
# 14  Scaling of economic benefits from green roof i...
# 15  Benefit-cost analysis of stormwater green infr...
# 16  Economic evaluation of green-roof environmenta...
# 17  Are Neighborhood-level SUDS Worth it? An asses...
# 18  Analysing Green Roof Effects in an Urban Envir...
# 19  Benefit-Cost Analysis of Green Roof Initiative...
# 20  The socioeconomic feasibility of greening rail...
# 21  Socioeconomic feasibility of green roofs and w...
# 22  The Valuation of Public and Private Benefits o...
# 23  Enhancing the Economic Value of Large Investme...
# 24  An environmental cost-benefit analysis of alte...
# 25  Comprehensive performance Evaluation of Green ...
# 26  Integrating cost-benefits analysis and life cy...
# 27  What's the economic value of greening transpor...
# 28  What's the economic value of greening transpor...
# 29  Green Roof Adoption in Atlanta. Georgia: The E...
#
#                                                 Notes Local analysis  \
# 0   commercial buildings: Although the whole area ...            NaN
# 1   € values concerned with the UK were converted ...              x
# 2   Maintenance cost: includes water sampling cost...              x
# 3   $ values were converted to MYR currency with t...            NaN
# 4                                                 NaN              x
# 5                                                 NaN            NaN
# 6                                                 NaN            NaN
# 7                       Extensive roof depth: 5-15 cm            NaN
# 8                                                 NaN            NaN
# 9   $ values were converted to KRW currency with t...            NaN
# 10                                                NaN            NaN
# 11                                                NaN              x
# 12  Additional data: occupant density = 8 m2/perso...            NaN
# 13  Sound insulation: high value is due to the fac...            NaN
# 14                                                NaN            NaN
# 15                                                NaN            NaN
# 16  $ values were converted to HK$ with the market...            NaN
# 17  Degree days for cooling were considered to be ...              x
# 18                                                NaN            NaN
# 19                                                NaN            NaN
# 20                                                NaN            NaN
# 21                                                NaN            NaN
# 22  Social discount rate: 3 (year 0-30) and then 3...            NaN
# 23  $ values were converted to UYU currency with t...            NaN
# 24                                                NaN            NaN
# 25                                                NaN            NaN
# 26                                                NaN            NaN
# 27                                                NaN            NaN
# 28                                                NaN            NaN
# 29                                                NaN            NaN
#
#    Unnamed: 13
# 0          NaN
# 1          yes
# 2          NaN
# 3          yes
# 4          NaN
# 5          yes
# 6          yes
# 7          yes
# 8          yes
# 9          yes
# 10         yes
# 11         NaN
# 12         NaN
# 13         NaN
# 14         yes
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         yes
# 25         yes
# 26         NaN
# 27         NaN
# 28         yes
# 29         yes

# %%
# Select local analysis data
local_CBA_data = raw_CBA_data[raw_CBA_data["Local analysis"]=="x"]
local_CBA_data
# Out:
#     Private discount rate (min) [%]  Private discount rate (max) [%]  \
# 1                               NaN                              NaN
# 2                               9.0                              9.0
# 4                               NaN                              NaN
# 11                              NaN                              NaN
# 17                              3.0                              3.0
#
#     Social discount rate (min) [%]  Social discount rate (max) [%]  \
# 1                              NaN                             NaN
# 2                              4.0                             4.0
# 4                              2.0                             8.0
# 11                             4.0                             4.0
# 17                             3.0                             3.0
#
#     Non-specified type of iscount rate (min) [%]  \
# 1                                            NaN
# 2                                            NaN
# 4                                            NaN
# 11                                           NaN
# 17                                           NaN
#
#     Non-specified type of discount rate (max) [%]  Time horizon [years]  \
# 1                                             NaN                    20
# 2                                             NaN                    50
# 4                                             NaN                    55
# 11                                            NaN                    50
# 17                                            NaN                    50
#
#                  Authors  Year              Author and year  \
# 1         Ascione et al.  2013        Ascione et al. (2013)
# 2       Claus & Rousseau  2012      Claus & Rousseau (2012)
# 4     Bianchini & Hewage  2012    Bianchini & Hewage (2012)
# 11         Machac et al.  2016         Machac et al. (2016)
# 17  Johnson & Geisendorf  2019  Johnson & Geisendorf (2019)
#
#                                                 Study  \
# 1   Green roofs in European climates. Are effectiv...
# 2   Public versus private incentives to invest in ...
# 4   Probabilistic social cost-benefit analysis for...
# 11  Green and Blue Infrastructure: An Opportunity ...
# 17  Are Neighborhood-level SUDS Worth it? An asses...
#
#                                                 Notes Local analysis  \
# 1   € values concerned with the UK were converted ...              x
# 2   Maintenance cost: includes water sampling cost...              x
# 4                                                 NaN              x
# 11                                                NaN              x
# 17  Degree days for cooling were considered to be ...              x
#
#    Unnamed: 13
# 1          yes
# 2          NaN
# 4          NaN
# 11         NaN
# 17         NaN

# %%
# Plot the distribution of CBAs' time_horizon 

# prepare data for global and local analyses' plots
global_data = raw_CBA_data[["Time horizon [years]"]]
local_data = raw_CBA_data[raw_CBA_data["Local analysis"]=="x"]["Time horizon [years]"]

# generate boxplot with distribution of values (strip plot) for the global and, in a different color, for the local 
# analysis, additionally plot the and histogram of values for the global analysis on top of it.
f, (ax_hist, ax_box) = plt.subplots(2, sharex=True, figsize=(20,6),
                                    gridspec_kw={"height_ratios": (0.60, 0.4)})

sns.distplot(global_data, ax=ax_hist, bins= 6, kde= False)
sns.stripplot(global_data, jitter=0.23, ax=ax_box, size=13, color="orange")
sns.stripplot(local_data, jitter=0.2, ax=ax_box, size=13, color="green")

props = {
    'boxprops':{'facecolor':'aliceblue', 'edgecolor':'#1f77b4'},
    'medianprops':{'color':'g'},
    'whiskerprops':{'color':'#1f77b4'},
    'capprops':{'color':'black'}}

sns.boxplot(global_data, ax=ax_box,
            showmeans = True,
            meanprops={"marker":"x","markerfacecolor":"black", "markeredgecolor":"black", "markersize":15},
           **props)


ax_box.set(yticks=[])
sns.despine(ax=ax_hist)
sns.despine(ax=ax_box, left=True)

ax_box.set_xlim(0,80)
ax_hist.set_xlim(0,80)
ax_box.set_xlabel("Years",fontsize=25)
ax_hist.set_ylabel("Frequency",fontsize=25)
ax_box.tick_params(axis='x', which='major', labelsize=20)
ax_hist.tick_params(axis='x', which='major', labelsize=20)
ax_hist.tick_params(axis='y', which='major', labelsize=20)
f.tight_layout()

# Save the plot
plt.savefig("Figures/CBA time horizons strip_plot",dpi=300, bbox_inches = "tight")
# Out:
# C:\Users\Timme\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
x_global = pd.DataFrame(raw_CBA_data["Time horizon [years]"])
x_global = pd.merge(x_global, pd.Series(np.zeros(len(x_global)), name="local_analysis"), left_index=True, right_index=True)
x_local = pd.DataFrame(raw_CBA_data[raw_CBA_data["Local analysis"]=="x"]["Time horizon [years]"])
x_local = pd.merge(x_local, pd.Series(np.ones(len(x_local)), name="local_analysis"), left_index=True, right_index=True)

x_df = x_global.append(x_local, ignore_index= True)
x_df
# Out:
#     Time horizon [years]  local_analysis
# 0                     40             0.0
# 1                     20             0.0
# 2                     50             0.0
# 3                     50             0.0
# 4                     55             0.0
# 5                     40             0.0
# 6                     25             0.0
# 7                     40             0.0
# 8                     50             0.0
# 9                     10             0.0
# 10                    25             0.0
# 11                    50             0.0
# 12                    40             0.0
# 13                    40             0.0
# 14                    40             0.0
# 15                    50             0.0
# 16                    40             0.0
# 17                    50             0.0
# 18                    20             0.0
# 19                    20             0.0
# 20                    40             0.0
# 21                    40             0.0
# 22                    75             0.0
# 23                    30             0.0
# 24                    40             0.0
# 25                    20             0.0
# 26                    50             0.0
# 27                    40             0.0
# 28                    50             0.0
# 29                    40             0.0
# 30                    20             1.0
# 31                    50             1.0
# 32                    55             1.0
