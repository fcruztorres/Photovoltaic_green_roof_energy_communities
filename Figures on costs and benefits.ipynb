# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
raw_data = pd.read_csv("Costs and benefits of photovoltaic-green roofs.csv")
raw_data
# Out:
#                   Technology Green roof type Plant species     Irrigation  \
# 0    Photovoltaic-green roof       Extensive           NaN  not mentioned
# 1    Photovoltaic-green roof       Extensive           NaN  not mentioned
# 2    Photovoltaic-green roof       Extensive           NaN  not mentioned
# 3    Photovoltaic-green roof       Extensive           NaN  not mentioned
# 4    Photovoltaic-green roof       Extensive           NaN  not mentioned
# ..                       ...             ...           ...            ...
# 775  Photovoltaic-green roof       Extensive           NaN  not mentioned
# 776  Photovoltaic-green roof       Extensive           NaN  not mentioned
# 777  Photovoltaic-green roof       Extensive           NaN  not mentioned
# 778               Green roof       Extensive           NaN             no
# 779               Green roof       Extensive           NaN            NaN
#
#     PV panel type PV panels and GR locations  Distance PV-green roof [cm]  \
# ...

# %%
air_quality_issues = raw_data[(raw_data["Item"]=="Air quality enhancement") |
                              (raw_data["Item"]=="CO2 emission reduction") |
                              (raw_data["Item"]=="CO2 uptake") ]
air_quality_issues.boxplot(column="Adjusted Monetary value [EU27 2019 €/m2]", by=["Item"], figsize=(11,6), fontsize=14, showfliers=False)
plt.ylabel('Adjusted Monetary value [EU27 2019 €/m2/year]', fontsize=14)
plt.title('', fontsize=15)
plt.savefig("Figures/Air quality overlaps",dpi=300, bbox_inches = "tight")

# %%
air_quality_issues.groupby(["Item"])["Adjusted Monetary value [EU27 2019 €/m2]"].describe()
# Out:
#                          count      mean       std       min       25%  \
# Item
# Air quality enhancement   29.0  0.455990  0.665748  0.014412  0.077668
# CO2 emission reduction    20.0  0.564277  1.148730 -0.043524  0.033386
# CO2 uptake                14.0  0.442171  1.492078  0.000000  0.000146
#
#                               50%       75%       max
# Item
# Air quality enhancement  0.130583  0.596085  3.070190
# CO2 emission reduction   0.189541  0.290176  4.337851
# CO2 uptake               0.002219  0.027248  5.606586

# %%
sound = raw_data[(raw_data["Item"]=="Sound insulation")]

sound.boxplot(column="Adjusted Monetary value [EU27 2019 €/m2]", by=["Item"], figsize=(5,6), fontsize=14, showfliers=True)
plt.ylabel('Adjusted Monetary value [EU27 2019 €/m2/year]', fontsize=14)
plt.title('', fontsize=15)
plt.savefig("Figures/Sound",dpi=300, bbox_inches = "tight")

# %%
overview_data = pd.read_csv("Costs and benefits of photovoltaic-green roofs - selected benefits.csv")
overview_data[overview_data["Item"]=="Aesthetics increase"].boxplot(column="Adjusted Monetary value [EU27 2019 €/m2]", by=["Item"], figsize=(5,6), rot=0, fontsize= 15, showfliers=False)
# plt.ylabel('Adjusted Monetary value [EU27 2019 €/m2]', fontsize=14)
plt.title('', fontsize=15)
plt.ylabel('Adjusted Monetary value [EU27 2019 €/m2]', fontsize=14)
plt.savefig("Figures/Aesthetics increase",dpi=300, bbox_inches = "tight")

# %%
sound_aesth_prop_issues.groupby(["Item"])["Adjusted Monetary value [EU27 2019 €/m2]"].describe()

# %%
PV_perf_increase = raw_data[(raw_data["Item"]=="Photovoltaic output")]

PV_perf_increase.boxplot(column="Adjusted Monetary value [EU27 2019 €/m2]", by=["Item"], figsize=(4,6), showfliers=True)

plt.savefig("Figures/PV performance")

# %%
PV_perf_increase = raw_data[(raw_data["Item"]=="Photovoltaic performance increase") |
                           (raw_data["Item"]=="Photovoltaic output")]

PV_perf_increase.boxplot(column="Adjusted Monetary value [EU27 2019 €/m2]", by=["Item"], figsize=(10,6), showfliers=True)
plt.savefig("Figures/PV")

# %%
overview_data = pd.read_csv("Costs and benefits of photovoltaic-green roofs - selected benefits.csv")

costs = overview_data[(overview_data["Item type"]=="cost") & 
                      (overview_data["Base case roof"]=="black roof") & 
                      (overview_data["Item"]!="Installation of green roof (gross)") & 
                      (overview_data["Item"]!="Maintenance of green roof (gross)") & 
                      (overview_data["Item"]!="Maintenance of green roof") &
                     (overview_data["Item"]!="Maintenance of green roof (net)")]
costs.boxplot(column="Adjusted Monetary value [EU27 2019 €/m2]", by=["Item"], figsize=(9,6), rot=90, fontsize= 15, showfliers=True)
plt.ylabel('Adjusted Monetary value [EU27 2019 €/m2]', fontsize=14)
plt.title('', fontsize=15)
plt.savefig("Figures/Overview of one-time costs",dpi=300, bbox_inches = "tight")

# %%
maintenance = overview_data[(overview_data["Item"]=="Maintenance of green roof (net)")]
maintenance.boxplot(column="Adjusted Monetary value [EU27 2019 €/m2]", by=["Item"], figsize=(4,6), rot=90, fontsize= 15, showfliers=True)
plt.ylabel('Adjusted Monetary value [EU27 2019 €/m2/year]', fontsize=14)
plt.title('', fontsize=15)
plt.savefig("Figures/Maintenance",dpi=300, bbox_inches = "tight")

# %%
costs.groupby(["Item"])["Adjusted Monetary value [EU27 2019 €/m2]"].describe()
# Out:
#                                           count       mean        std  \
# Item
# Air pollution from green roof production   11.0  15.033849   7.868930
# CO2 emissions from green roof production    6.0  12.643817   8.202810
# Disposal of green roof                     13.0   8.329782  22.941330
# Installation of green roof (net)           48.0  84.374990  46.535960
# Replacement of green roof                   9.0  43.209350  26.213688
#
#                                                 min        25%        50%  \
# Item
# Air pollution from green roof production   3.065852  10.270107  13.520695
# CO2 emissions from green roof production   3.065852   5.679562  13.520695
# Disposal of green roof                     0.001934   0.022245   0.086076
# Installation of green roof (net)           8.026549  40.570805  96.973154
# Replacement of green roof                 30.683964  30.703274  30.954307
#
#                                                  75%         max
# Item
# ...

# %%
# Distribution summary statistics of maintenance costs: 
# unfortunately cost items without irrigation are too few to draw general conclusions.
costs[costs["Item"]=="Maintenance of green roof (net)"].groupby("Irrigation")["Adjusted Monetary value [EU27 2019 €/m2]"].describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-a10dd5b4badb> in <module>()
#       1 # Distribution summary statistics of maintenance costs:
#       2 # unfortunately cost items without irrigation are too few to draw general conclusions.
# ----> 3 costs[costs["Item"]=="Maintenance of green roof (net)"].groupby("Irrigation")["Adjusted Monetary value [EU27 2019 €/m2]"].describe()
#
# C:\Users\Timme\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in describe(self, **kwargs)
#     634         if self.axis == 1:
#     635             return result.T
# --> 636         return result.unstack()
#     637
#     638     def value_counts(
#
# C:\Users\Timme\Anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
#    3548         from pandas.core.reshape.reshape import unstack
#    3549
# ...

# %%
benefits = overview_data[(overview_data["Item type"]=="benefit") &
                        (overview_data["Base case roof"]=="black roof") ]
benefits.boxplot(column="Adjusted Monetary value [EU27 2019 €/m2]", by=["Item"], figsize=(20,6), rot=45, showfliers=True)
plt.ylabel('Adjusted Monetary value [EU27 2019 €/m2]', fontsize=14)
plt.title('', fontsize=15)
plt.savefig("Figures/Overview of the benefits",dpi=300, bbox_inches = "tight")

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(50,10)) # create 1x2 array of subplots

benefits.boxplot(column="Adjusted Monetary value [EU27 2019 €/m2]", by=["Item"], figsize=(20,6), rot=45, fontsize= 15, showfliers=False, ax=axes[0])
plt.title('Adjusted Monetary value [EU27 2019 €/m2]', fontsize=15)

overview_data[overview_data["Item"]=="Aesthetics increase"].boxplot(column="Adjusted Monetary value [EU27 2019 €/m2]", by=["Item"], figsize=(5,6), rot=0, fontsize= 15, showfliers=False, ax=axes[1])
plt.title('Adjusted Monetary value [EU27 2019 €/m2]', fontsize=15)
plt.tight_layout
plt.show()

# %%
benefits = overview_data[(overview_data["Item type"]=="benefit") & 
                         (overview_data["Base case roof"]=="black roof") & 
                         (overview_data["Item"]!="Aesthetics increase") &
                         (overview_data["Item"]!="Air quality enhancement") &
                        (overview_data["Item"]!="CO2 emission reduction") &
                        (overview_data["Item"]!="CO2 uptake") ]

benefits.boxplot(column="Adjusted Monetary value [EU27 2019 €/m2]", by=["Item"], figsize=(15,6), rot=90, fontsize= 15, showfliers=True)
plt.ylabel('Adjusted Monetary value [EU27 2019 €/m2/year]', fontsize=14)
plt.title('', fontsize=15)
plt.savefig("Figures/Zoom on smaller benefits",dpi=300, bbox_inches = "tight")

# %%
benefits.groupby(["Item"])["Adjusted Monetary value [EU27 2019 €/m2]"].describe()
# Out:
#                                                     count        mean  \
# Item
# Aesthetics increase                                  25.0  130.266818
# Air quality enhancement                              23.0    0.549268
# Biodiversity enhancement                             17.0    0.526730
# CO2 emission reduction                               17.0    0.666605
# CO2 uptake                                           10.0    0.566407
# Energy consumption reduction (cooling)               16.0    1.623667
# Energy consumption reduction (heating and cooling)   77.0   11.047197
# Energy consumption reduction (heating)               18.0    4.214728
# Fire risk reduction                                  11.0    0.098307
# Flood risk reduction                                 24.0    2.479864
# Longevity increase                                   23.0    5.204401
# Photovoltaic output                                  12.0   14.477491
# ...
